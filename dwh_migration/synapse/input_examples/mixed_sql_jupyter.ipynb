-- %% [markdown]
-- This notebook's default language is SQL and contains mixed code blocks (Python and SQL).

-- %%
%%pyspark
print("hello world")
-- Out:
-- StatementMeta(test, 7, 2, Finished, Available, Finished, False)
-- hello world

-- %%
SELECT 'HELLO WORLD';
-- Out:
-- StatementMeta(test, 7, 3, Finished, Available, Finished, False)
-- <Spark SQL result set with 1 rows and 1 fields>
