# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS gergeljkis_external_location_dashboards
URL 'abfss://test@gergeljkissa.dfs.core.windows.net/dashboards'
WITH (STORAGE CREDENTIAL `gergeljkis-storage-cred`);

# %%
# %sql
CREATE CATALOG IF NOT EXISTS dashboards
MANAGED LOCATION 'abfss://test@gergeljkissa.dfs.core.windows.net/dashboards';
